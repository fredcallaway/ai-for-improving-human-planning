# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_context('notebook', font_scale=1.3)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from analysis_utils import *
data = get_data('maze-0.1', '../data/human/')

# %%
data['maze'].events[0]
# Out:
# [{'event': 'draw 29 17', 'time': 5375},
#  {'event': 'draw 29 16', 'time': 6526},
#  {'event': 'draw 29 18', 'time': 7275},
#  {'event': 'draw 29 19', 'time': 7602},
#  {'event': 'draw 30 19', 'time': 8019},
#  {'event': 'draw 31 19', 'time': 8136},
#  {'event': 'draw 31 18', 'time': 8420},
#  {'event': 'draw 31 17', 'time': 8537},
#  {'event': 'draw 31 16', 'time': 8636},
#  {'event': 'draw 31 15', 'time': 8736},
#  {'event': 'draw 31 14', 'time': 8836},
#  {'event': 'draw 31 13', 'time': 8937},
#  {'event': 'draw 31 12', 'time': 9020},
#  {'event': 'draw 31 11', 'time': 9104},
#  {'event': 'draw 30 11', 'time': 9453},
#  {'event': 'draw 29 11', 'time': 9603},
#  {'event': 'draw 29 12', 'time': 9886},
#  {'event': 'draw 29 13', 'time': 10004},
#  {'event': 'draw 28 13', 'time': 10104},
#  {'event': 'draw 27 13', 'time': 10320},
#  {'event': 'draw 27 12', 'time': 10620},
#  {'event': 'draw 27 11', 'time': 10737},
#  {'event': 'draw 26 11', 'time': 10971},
# ...
